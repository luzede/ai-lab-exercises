# %% [markdown]
# ##### ❗Προσοχή: Συμπληρώστε τα ονόματα των μελών της ομάδας σας
#
#      Ονοματεπώνυμο 1ου μέλους:
#              email 1ου μέλους:
#
#      Ονοματεπώνυμο 2ου μέλους:
#              email 2ου μέλους:

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Ενότητα 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd
#path = '/content/drive/MyDrive/'
# Διάβασμα του αρχείου 'movie_metadata.csv'
data = pd.read_csv("movies_metadata.csv")
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data
#data.head()
# Out:
# /tmp/ipykernel_38621/3165232806.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'UNK' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.fillna("UNK", inplace=True)

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title'))
  language = clean_text(getattr(row, 'language'))
  vote_average = getattr(row, 'vote_average')
  title_year = getattr(row, 'title_year')
  director = clean_text(getattr(row, 'director_name'))
  country = clean_text(getattr(row, 'country'))


  for genre in getattr(row, 'genres').split("|"):
    literals.append("genre('"+ movie_title +"','"+ genre +"')")

  for actor in getattr(row, 'actor_1_name').split("|"):
    literals.append("actor('"+ movie_title +"','"+ actor +"')")

  for actor in getattr(row, 'actor_2_name').split("|"):
    literals.append("actor('"+ movie_title +"','"+ actor +"')")

  for actor in getattr(row, 'actor_3_name').split("|"):
    literals.append("actor('"+ movie_title +"','"+ actor +"')")
    print("actor('"+ movie_title +"','"+ actor +"')")

#Η Prolog θέλει τα κατηγορήματά της με την σειρά
literals.sort()
for literal in literals:
  prolog.assertz(literal)
#   print (literal +'.')

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
prolog.consult("db.pl")
# Out:
# actor('Avatar','Stephen Lang')
# actor('Pirates of the Caribbean: At Worlds End','Stellan Skarsgård')
# actor('Spectre','Ralph Fiennes')
# actor('The Dark Knight Rises','Anne Hathaway')
# actor('John Carter','Willem Dafoe')
# actor('Spider-Man 3','Thomas Haden Church')
# actor('Tangled','Ron Perlman')
# actor('Avengers: Age of Ultron','Chris Evans')
# actor('Harry Potter and the Half-Blood Prince','Tom Felton')
# actor('Batman v Superman: Dawn of Justice','Amy Adams')
# actor('Superman Returns','James Marsden')
# actor('Quantum of Solace','Judi Dench')
# actor('Pirates of the Caribbean: Dead Mans Chest','Stellan Skarsgård')
# actor('The Lone Ranger','Helena Bonham Carter')
# actor('Man of Steel','Kevin Costner')
# actor('The Chronicles of Narnia: Prince Caspian','Skandar Keynes')
# actor('The Avengers','Chris Hemsworth')
# actor('Pirates of the Caribbean: On Stranger Tides','Kevin McNally')
# actor('Men in Black 3','Michael Stuhlbarg')
# actor('The Hobbit: The Battle of the Five Armies','Ken Stott')
# actor('The Amazing Spider-Man','Denis Leary')
# actor('Robin Hood','William Hurt')
# actor('The Hobbit: The Desolation of Smaug','Ken Stott')
# actor('The Golden Compass','Sam Elliott')
# actor('King Kong','Thomas Kretschmann')
# actor('Titanic','Billy Zane')
# actor('Captain America: Civil War','Sebastian Stan')
# actor('Battleship','Brooklyn Decker')
# actor('Jurassic World','Vincent D'Onofrio')
# actor('Skyfall','Ralph Fiennes')
# actor('Spider-Man 2','Alfred Molina')
# actor('Iron Man 3','Guy Pearce')
# actor('Alice in Wonderland','Helena Bonham Carter')
# actor('X-Men: The Last Stand','Patrick Stewart')
# actor('Monsters University','Helen Mirren')
# actor('Transformers: Revenge of the Fallen','Rainn Wilson')
# actor('Transformers: Age of Extinction','Nicola Peltz')
# actor('Oz: The Great and Powerful','Michelle Williams')
# actor('The Amazing Spider-Man 2','Dane DeHaan')
# actor('TRON: Legacy','Bruce Boxleitner')
# actor('Cars 2','Emily Mortimer')
# actor('Green Lantern','Tim Robbins')
# actor('Toy Story 3','Joan Cusack')
# actor('Terminator Salvation','Moon Bloodgood')
# actor('Furious 7','Michelle Rodriguez')
# actor('World War Z','Sterling Jerins')
# actor('X-Men: Days of Future Past','Jennifer Lawrence')
# actor('Star Trek Into Darkness','Karl Urban')
# actor('Jack the Giant Slayer','Stanley Tucci')
# actor('The Great Gatsby','Joel Edgerton')
# actor('Prince of Persia: The Sands of Time','Alfred Molina')
# actor('Pacific Rim','Ron Perlman')
# actor('Transformers: Dark of the Moon','Frances McDormand')
# actor('Indiana Jones and the Kingdom of the Crystal Skull','Ray Winstone')
# actor('The Good Dinosaur','Frances McDormand')
# actor('Brave','Emma Thompson')
# actor('Star Trek Beyond','Simon Pegg')
# actor('WALL·E','Fred Willard')
# actor('Rush Hour 3','Max von Sydow')
# actor('2012','Thandie Newton')
# actor('A Christmas Carol','Daryl Sabara')
# actor('Jupiter Ascending','Eddie Redmayne')
# actor('The Legend of Tarzan','Samuel L. Jackson')
# actor('The Chronicles of Narnia: The Lion, the Witch and the Wardrobe','Georgie Henley')
# actor('X-Men: Apocalypse','Nicholas Hoult')
# actor('The Dark Knight','Michael Caine')
# actor('Up','Bob Peterson')
# actor('Monsters vs Aliens','Paul Rudd')
# actor('Iron Man','Shaun Toub')
# actor('Hugo','Chloë Grace Moretz')
# actor('Wild Wild West','Salma Hayek')
# actor('The Mummy: Tomb of the Dragon Emperor','Maria Bello')
# actor('Suicide Squad','Viola Davis')
# actor('Evan Almighty','Jimmy Bennett')
# actor('Edge of Tomorrow','Bill Paxton')
# actor('Waterworld','R. D. Call')
# actor('G.I. Joe: The Rise of Cobra','Sienna Miller')
# actor('Inside Out','Bill Hader')
# actor('The Jungle Book','Idris Elba')
# actor('Iron Man 2','Scarlett Johansson')
# actor('Snow White and the Huntsman','Sam Claflin')
# actor('Maleficent','Sam Riley')
# actor('Dawn of the Planet of the Apes','Keri Russell')
# actor('The Lovers','Alice Englert')
# actor('47 Ronin','Tadanobu Asano')
# actor('Captain America: The Winter Soldier','Robert Redford')
# actor('Shrek Forever After','Antonio Banderas')
# actor('Tomorrowland','Thomas Robinson')
# actor('Big Hero 6','T.J. Miller')
# actor('Wreck-It Ralph','Jane Lynch')
# actor('The Polar Express','Peter Scolari')
# actor('Independence Day: Resurgence','Maika Monroe')
# actor('How to Train Your Dragon','America Ferrera')
# actor('Terminator 3: Rise of the Machines','Kristanna Loken')
# actor('Guardians of the Galaxy','Vin Diesel')
# actor('Interstellar','Michael Caine')
# actor('Inception','Tom Hardy')
# actor('Shin Godzilla','Kengo Kora')
# actor('The Hobbit: An Unexpected Journey','Andy Serkis')
# actor('The Fast and the Furious','Jordana Brewster')
# actor('The Curious Case of Benjamin Button','Julia Ormond')
# actor('X-Men: First Class','Kevin Bacon')
# actor('The Hunger Games: Mockingjay - Part 2','Woody Harrelson')
# actor('The Sorcerers Apprentice','Alfred Molina')
# actor('Poseidon','Jacinda Barrett')
# actor('Alice Through the Looking Glass','Helena Bonham Carter')
# actor('Shrek the Third','Julie Andrews')
# actor('Warcraft','Robert Kazinsky')
# actor('Terminator Genisys','Jai Courtney')
# actor('The Chronicles of Narnia: The Voyage of the Dawn Treader','Gary Sweet')
# actor('Pearl Harbor','Cuba Gooding Jr.')
# actor('Transformers','Rachael Taylor')
# actor('Alexander','Jared Leto')
# actor('Harry Potter and the Order of the Phoenix','Michael Gambon')
# actor('Harry Potter and the Goblet of Fire','Ralph Fiennes')
# actor('Hancock','Jae Head')
# actor('I Am Legend','Salli Richardson-Whitfield')
# actor('Charlie and the Chocolate Factory','AnnaSophia Robb')
# actor('Ratatouille','Brian Dennehy')
# actor('Batman Begins','Katie Holmes')
# actor('Madagascar: Escape 2 Africa','Chris Rock')
# actor('Night at the Museum: Battle of the Smithsonian','Hank Azaria')
# actor('X-Men Origins: Wolverine','Lynn Collins')
# actor('The Matrix Revolutions','Hugo Weaving')
# actor('Frozen','Josh Gad')
# actor('The Matrix Reloaded','Hugo Weaving')
# actor('Thor: The Dark World','Anthony Hopkins')
# actor('Mad Max: Fury Road','Hugh Keays-Byrne')
# actor('Angels & Demons','Stellan Skarsgård')
# actor('Thor','Anthony Hopkins')
# actor('Bolt','Mark Walton')
# actor('G-Force','Jon Favreau')
# actor('Wrath of the Titans','Edgar Ramírez')
# actor('Dark Shadows','Jackie Earle Haley')
# actor('Mission: Impossible - Rogue Nation','Jeremy Renner')
# actor('The Wolfman','Hugo Weaving')
# actor('Bee Movie','Matthew Broderick')
# actor('Kung Fu Panda 2','Gary Oldman')
# actor('The Last Airbender','Dev Patel')
# actor('Mission: Impossible III','Billy Crudup')
# actor('White House Down','Maggie Gyllenhaal')
# actor('Mars Needs Moms','Breckin Meyer')
# actor('Flushed Away','Jean Reno')
# actor('Pan','Rooney Mara')
# actor('Mr. Peabody & Sherman','Allison Janney')
# actor('Troy','Brian Cox')
# actor('Madagascar 3: Europes Most Wanted','Frances McDormand')
# actor('Die Another Day','Rick Yune')
# actor('Ghostbusters','Leslie Jones')
# actor('Armageddon','Liv Tyler')
# actor('Men in Black II','Lara Flynn Boyle')
# actor('Beowulf','Robin Wright')
# actor('Kung Fu Panda 3','Angelina Jolie')
# actor('Mission: Impossible - Ghost Protocol','Paula Patton')
# actor('Rise of the Guardians','Isla Fisher')
# actor('Fun with Dick and Jane','Richard Jenkins')
# actor('The Last Samurai','Chad Lindberg')
# actor('Exodus: Gods and Kings','Aaron Paul')
# actor('Star Trek','Eric Bana')
# actor('Spider-Man','James Franco')
# actor('How to Train Your Dragon 2','Jonah Hill')
# actor('Gods of Egypt','Courtney Eaton')
# actor('Stealth','Sam Shepard')
# actor('Watchmen','Jeffrey Dean Morgan')
# actor('Lethal Weapon 4','Rene Russo')
# actor('Hulk','Josh Lucas')
# actor('G.I. Joe: Retaliation','Bruce Willis')
# actor('Sahara','William H. Macy')
# actor('Final Fantasy: The Spirits Within','Ving Rhames')
# actor('Captain America: The First Avenger','Hayley Atwell')
# actor('The World Is Not Enough','Denise Richards')
# actor('Master and Commander: The Far Side of the World','Billy Boyd')
# actor('The Twilight Saga: Breaking Dawn - Part 2','Peter Facinelli')
# actor('Happy Feet Two','E.G. Daily')
# actor('The Incredible Hulk','William Hurt')
# actor('The BFG','Jemaine Clement')
# actor('The Revenant','Domhnall Gleeson')
# actor('Turbo','Samuel L. Jackson')
# actor('Rango','Bill Nighy')
# actor('Penguins of Madagascar','Conrad Vernon')
# actor('The Bourne Ultimatum','Scott Glenn')
# actor('Kung Fu Panda','Jackie Chan')
# actor('Ant-Man','Corey Stoll')
# actor('The Hunger Games: Catching Fire','Woody Harrelson')
# actor('Home','Jennifer Lopez')
# actor('War of the Worlds','Justin Chatwin')
# actor('Bad Boys II','Gabrielle Union')
# actor('Puss in Boots','Billy Bob Thornton')
# actor('Salt','Daniel Olbrychski')
# actor('Noah','Logan Lerman')
# actor('The Adventures of Tintin','Nick Frost')
# actor('Harry Potter and the Prisoner of Azkaban','Gary Oldman')
# actor('Australia','David Wenham')
# actor('After Earth','Zoë Kravitz')
# actor('Dinosaur','Max Casella')
# actor('Night at the Museum: Secret of the Tomb','Robin Williams')
# actor('Megamind','Jonah Hill')
# actor('Harry Potter and the Philosophers Stone','Richard Harris')
# actor('R.I.P.D.','Stephanie Szostak')
# actor('Pirates of the Caribbean: The Curse of the Black Pearl','Keira Knightley')
# actor('The Hunger Games: Mockingjay - Part 1','Woody Harrelson')
# actor('The Da Vinci Code','Paul Bettany')
# actor('Rio 2','Jamie Foxx')
# actor('X2','Halle Berry')
# actor('Fast Five','Tyrese Gibson')
# actor('Sherlock Holmes: A Game of Shadows','Noomi Rapace')
# actor('Clash of the Titans','Gemma Arterton')
# actor('Total Recall','Ronny Cox')
# actor('The 13th Warrior','Daniel Southern')
# actor('The Bourne Legacy','Scott Glenn')
# actor('Batman & Robin','Uma Thurman')
# actor('How the Grinch Stole Christmas','Christine Baranski')
# actor('The Day After Tomorrow','Dash Mihok')
# actor('Mission: Impossible II','Ving Rhames')
# actor('The Perfect Storm','John C. Reilly')
# actor('Fantastic 4: Rise of the Silver Surfer','Michael Chiklis')
# actor('Life of Pi','Gautam Belur')
# actor('Ghost Rider','Donal Logue')
# actor('Jason Bourne','Vincent Cassel')
# actor('Charlies Angels: Full Throttle','Bernie Mac')
# actor('Prometheus','Idris Elba')
# actor('Stuart Little 2','Jonathan Lipnicki')
# actor('Elysium','Alice Braga')
# actor('The Chronicles of Riddick','Colm Feore')
# actor('RoboCop','Abbie Cornish')
# actor('Speed Racer','Susan Sarandon')
# actor('How Do You Know','Jack Nicholson')
# actor('Knight and Day','Viola Davis')
# actor('Oblivion','Andrea Riseborough')
# actor('Star Wars: Episode III - Revenge of the Sith','Ian McDiarmid')
# actor('Star Wars: Episode II - Attack of the Clones','Ian McDiarmid')
# actor('Monsters, Inc.','Steve Buscemi')
# actor('The Wolverine','Will Yun Lee')
# actor('Star Wars: Episode I - The Phantom Menace','Jake Lloyd')
# actor('The Croods','Catherine Keener')
# actor('Asterix at the Olympic Games','José Garcia')
# actor('Windtalkers','Noah Emmerich')
# actor('The Huntsman: Winters War','Jessica Chastain')
# actor('Teenage Mutant Ninja Turtles','Alan Ritchson')
# actor('Gravity','Orto Ignatiussen')
# actor('Dantes Peak','Jeremy Foley')
# actor('Teenage Mutant Ninja Turtles: Out of the Shadows','Laura Linney')
# actor('Fantastic Four','Jamie Bell')
# actor('Night at the Museum','Robin Williams')
# actor('San Andreas','Ioan Gruffudd')
# actor('Tomorrow Never Dies','Teri Hatcher')
# actor('The Patriot','Jason Isaacs')
# actor('Oceans Twelve','Julia Roberts')
# actor('Mr. & Mrs. Smith','Adam Brody')
# actor('Insurgent','Ansel Elgort')
# actor('The Aviator','John C. Reilly')
# actor('Gullivers Travels','Jason Segel')
# actor('The Green Hornet','Cameron Diaz')
# actor('300: Rise of an Empire','Callan Mulvey')
# actor('The Smurfs','Sofía Vergara')
# actor('Home on the Range','Steve Buscemi')
# actor('Allegiant','Miles Teller')
# actor('Real Steel','Anthony Mackie')
# actor('The Smurfs 2','Jayma Mays')
# actor('Speed 2: Cruise Control','Temuera Morrison')
# actor('Enders Game','Abigail Breslin')
# actor('Live Free or Die Hard','Cliff Curtis')
# actor('The Lord of the Rings: The Fellowship of the Ring','Orlando Bloom')
# actor('Around the World in 80 Days','Robert Fyfe')
# actor('Ali','Mario Van Peebles')
# actor('The Cat in the Hat','Kelly Preston')
# actor('I, Robot','James Cromwell')
# actor('Kingdom of Heaven','Marton Csokas')
# actor('Stuart Little','Jonathan Lipnicki')
# actor('The Princess and the Frog','Michael-Leon Wooley')
# actor('The Martian','Jeff Daniels')
# actor('The Island','Sean Bean')
# actor('Town & Country','Garry Shandling')
# actor('Gone in Sixty Seconds','Delroy Lindo')
# actor('Gladiator','Oliver Reed')
# actor('Minority Report','Max von Sydow')
# actor('Harry Potter and the Chamber of Secrets','Richard Harris')
# actor('Casino Royale','Judi Dench')
# actor('Planet of the Apes','Michael Clarke Duncan')
# actor('Terminator 2: Judgment Day','Edward Furlong')
# actor('Public Enemies','Billy Crudup')
# actor('American Gangster','Josh Brolin')
# actor('True Lies','Bill Paxton')
# actor('The Taking of Pelham 1 2 3','Victor Gojcaj')
# actor('Little Fockers','Dustin Hoffman')
# actor('The Other Guys','Samuel L. Jackson')
# actor('Eraser','James Coburn')
# actor('Django Unchained','Kerry Washington')
# actor('The Hunchback of Notre Dame','Kevin Kline')
# actor('The Emperors New Groove','Patrick Warburton')
# actor('The Expendables 2','Bruce Willis')
# actor('National Treasure','Sean Bean')
# actor('Eragon','Robert Carlyle')
# actor('Where the Wild Things Are','James Gandolfini')
# actor('Epic','Jason Sudeikis')
# actor('The Tourist','Timothy Dalton')
# actor('End of Days','Robin Tunney')
# actor('Blood Diamond','Kagiso Kuypers')
# actor('The Wolf of Wall Street','Kyle Chandler')
# actor('Batman Forever','Nicole Kidman')
# actor('Starship Troopers','Jake Busey')
# actor('Cloud Atlas','Hugo Weaving')
# actor('Legend of the Guardians: The Owls of GaHoole','Joel Edgerton')
# actor('Catwoman','Lambert Wilson')
# actor('Hercules','Rufus Sewell')
# actor('Treasure Planet','Emma Thompson')
# actor('Land of the Lost','Jorma Taccone')
# actor('The Expendables 3','Arnold Schwarzenegger')
# actor('Point Break','Delroy Lindo')
# actor('Son of the Mask','Kal Penn')
# actor('In the Heart of the Sea','Brendan Gleeson')
# actor('The Adventures of Pluto Nash','Joe Pantoliano')
# actor('Green Zone','Amy Ryan')
# actor('The Peanuts Movie','Hadley Belle Miller')
# actor('The Spanish Prisoner','Rebecca Pidgeon')
# actor('The Mummy Returns','Arnold Vosloo')
# actor('Gangs of New York','Liam Neeson')
# actor('The Flowers of War','Zhang Xinyi')
# actor('Surfs Up','Jon Heder')
# actor('The Stepford Wives','Glenn Close')
# actor('Black Hawk Down','Tom Sizemore')
# actor('The Campaign','Jason Sudeikis')
# actor('The Fifth Element','Milla Jovovich')
# actor('Sex and the City 2','Kim Cattrall')
# actor('The Road to El Dorado','Armand Assante')
# actor('Ice Age: Continental Drift','Denis Leary')
# actor('Cinderella','Helena Bonham Carter')
# actor('The Lovely Bones','Saoirse Ronan')
# actor('Finding Nemo','Willem Dafoe')
# actor('The Lord of the Rings: The Return of the King','Liv Tyler')
# actor('The Lord of the Rings: The Two Towers','Liv Tyler')
# actor('Seventh Son','Alicia Vikander')
# actor('Lara Croft: Tomb Raider','Noah Taylor')
# actor('Transcendence','Kate Mara')
# actor('Jurassic Park III','Trevor Morgan')
# actor('Rise of the Planet of the Apes','Brian Cox')
# actor('The Spiderwick Chronicles','Sarah Bolger')
# actor('A Good Day to Die Hard','Mary Elizabeth Winstead')
# actor('The Alamo','Patrick Wilson')
# actor('The Incredibles','Jason Lee')
# actor('Cutthroat Island','Maury Chaykin')
# actor('Percy Jackson & the Olympians: The Lightning Thief','Jake Abel')
# actor('Men in Black','Vincent D'Onofrio')
# actor('Toy Story 2','Kelsey Grammer')
# actor('Unstoppable','Ethan Suplee')
# actor('Rush Hour 2','Roselyn Sánchez')
# actor('What Lies Beneath','James Remar')
# actor('Cloudy with a Chance of Meatballs','Mr. T')
# actor('Ice Age: Dawn of the Dinosaurs','Queen Latifah')
# actor('The Secret Life of Walter Mitty','Shirley MacLaine')
# actor('Charlies Angels','Bill Murray')
# actor('The Departed','Mark Wahlberg')
# actor('Mulan','Lea Salonga')
# actor('Tropic Thunder','Nick Nolte')
# actor('The Girl with the Dragon Tattoo','Goran Visnjic')
# actor('Die Hard: With a Vengeance','Graham Greene')
# actor('Sherlock Holmes','Mark Strong')
# actor('Ben-Hur','Nazanin Boniadi')
# actor('Atlantis: The Lost Empire','James Garner')
# actor('Alvin and the Chipmunks: The Road Chip','Matthew Gray Gubler')
# actor('Valkyrie','Bill Nighy')
# actor('You Dont Mess with the Zohan','Nick Swardson')
# actor('Pixels','Josh Gad')
# actor('A.I. Artificial Intelligence','Jake Thomas')
# actor('The Haunted Mansion','Marsha Thomason')
# actor('Contact','John Hurt')
# actor('Hollow Man','Kim Dickens')
# actor('The Interpreter','Jesper Christensen')
# actor('Percy Jackson: Sea of Monsters','Leven Rambin')
# actor('Lara Croft Tomb Raider: The Cradle of Life','Djimon Hounsou')
# actor('Now You See Me 2','Dave Franco')
# actor('The Saint','Henry Goodman')
# actor('Spy Game','Stephen Dillane')
# actor('Mission to Mars','Connie Nielsen')
# actor('Rio','Jane Lynch')
# actor('Bicentennial Man','Oliver Platt')
# actor('Volcano','Don Cheadle')
# actor('The Devils Own','Rubén Blades')
# actor('K-19: The Widowmaker','Joss Ackland')
# actor('Conan the Barbarian','Sandahl Bergman')
# actor('Cinderella Man','Craig Bierko')
# actor('The Nutcracker: The Untold Story','Frances de la Tour')
# actor('Seabiscuit','Tobey Maguire')
# actor('Twister','Jami Gertz')
# actor('Cast Away','Paul Sanchez')
# actor('Happy Feet','Hugh Jackman')
# actor('The Bourne Supremacy','Julia Stiles')
# actor('Air Force One','Wendy Crewson')
# actor('Oceans Eleven','Andy García')
# actor('The Three Musketeers','Ray Stevenson')
# actor('Hotel Transylvania','Kevin James')
# actor('Enchanted','Timothy Spall')
# actor('Safe House','Joel Kinnaman')
# actor('102 Dalmatians','Tim McInnerny')
# actor('Tower Heist','Alan Alda')
# actor('The Holiday','Jack Black')
# actor('Enemy of the State','Regina King')
# actor('Its Complicated','John Krasinski')
# actor('Oceans Thirteen','Al Pacino')
# actor('Open Season','Debra Messing')
# actor('Divergent','Miles Teller')
# actor('Enemy at the Gates','Joseph Fiennes')
# actor('The Rundown','Christopher Walken')
# actor('Last Action Hero','Charles Dance')
# actor('Memoirs of a Geisha','Tsai Chin')
# actor('The Fast and the Furious: Tokyo Drift','Shad Moss')
# actor('Arthur Christmas','Jim Broadbent')
# actor('Meet Joe Black','Jeffrey Tambor')
# actor('Collateral Damage','Cliff Curtis')
# actor('All That Jazz','Ann Reinking')
# actor('Mirror Mirror','Nathan Lane')
# actor('Scott Pilgrim vs. the World','Chris Evans')
# actor('The Core','Stanley Tucci')
# actor('Nutty Professor II: The Klumps','John Ales')
# actor('Scooby-Doo','Linda Cardellini')
# actor('Dredd','Wood Harris')
# actor('Click','David Hasselhoff')
# actor('Creepshow','Leslie Nielsen')
# actor('Cats & Dogs 2 : The Revenge of Kitty Galore','Bette Midler')
# actor('Jumper','Rachel Bilson')
# actor('Hellboy II: The Golden Army','Doug Jones')
# actor('Zodiac','Anthony Edwards')
# actor('The 6th Day','Michael Rooker')
# actor('Bruce Almighty','Catherine Bell')
# actor('The Expendables','Eric Roberts')
# actor('Mission: Impossible','Henry Czerny')
# actor('The Hunger Games','Woody Harrelson')
# actor('The Hangover Part II','Justin Bartha')
# actor('Batman Returns','Christopher Walken')
# actor('Over the Hedge','Wanda Sykes')
# actor('Lilo & Stitch','David Ogden Stiers')
# actor('Charlottes Web','Oprah Winfrey')
# actor('Deep Impact','Vanessa Redgrave')
# actor('RED 2','Helen Mirren')
# actor('The Longest Yard','Michael Irvin')
# actor('Alvin and the Chipmunks: Chipwrecked','Andy Buckley')
# actor('Grown Ups 2','David Spade')
# actor('Get Smart','Alan Arkin')
# actor('Somethings Gotta Give','Frances McDormand')
# actor('Shutter Island','Emily Mortimer')
# actor('Four Christmases','Sissy Spacek')
# actor('Robots','Mel Brooks')
# actor('Face/Off','Alessandro Nivola')
# actor('Bedtime Stories','Courteney Cox')
# actor('Road to Perdition','Liam Aiken')
# actor('Just Go with It','Nick Swardson')
# actor('Con Air','Ving Rhames')
# actor('Eagle Eye','Michael Chiklis')
# actor('Cold Mountain','Eileen Atkins')
# actor('The Book of Eli','Ray Stevenson')
# actor('Flubber','Raymond J. Barry')
# actor('The Haunting','Lili Taylor')
# actor('Space Jam','Dee Bradley Baker')
# actor('The Pink Panther','Beyoncé Knowles')
# actor('The Day the Earth Stood Still','Jaden Smith')
# actor('Conspiracy Theory','Cylk Cozart')
# actor('Fury','Michael Peña')
# actor('Six Days Seven Nights','Jacqueline Obradors')
# actor('Yogi Bear','Tom Cavanagh')
# actor('Spirit: Stallion of the Cimarron','Chopper Bernet')
# actor('Zookeeper','Nick Nolte')
# actor('Lost in Space','Mimi Rogers')
# actor('The Manchurian Candidate','Jon Voight')
# actor('Déjà Vu','Michael Brandon')
# actor('Hotel Transylvania 2','Kevin James')
# actor('Fantasia 2000','Bette Midler')
# actor('The Time Machine','Sienna Guillory')
# actor('Mighty Joe Young','Regina King')
# actor('Swordfish','Don Cheadle')
# actor('The Legend of Zorro','Julio Oscar Mechoso')
# actor('What Dreams May Come','Max von Sydow')
# actor('Little Nicky','Rhys Ifans')
# actor('The Brothers Grimm','Roger Ashton-Griffiths')
# actor('Mars Attacks!','Pierce Brosnan')
# actor('Evolution','Mathieu Goldfeld')
# actor('The Edge','Harold Perrineau')
# actor('Surrogates','James Cromwell')
# actor('Thirteen Days','Dylan Baker')
# actor('Daylight','Dan Hedaya')
# actor('Walking With Dinosaurs','Angourie Rice')
# actor('Battlefield Earth','Kim Coates')
# actor('Looney Tunes: Back in Action','Timothy Dalton')
# actor('Nine','Penélope Cruz')
# actor('Timeline','Billy Connolly')
# actor('The Postman','Larenz Tate')
# actor('Babe: Pig in the City','Magda Szubanski')
# actor('The Last Witch Hunter','Ólafur Darri Ólafsson')
# actor('Red Planet','Tom Sizemore')
# actor('Arthur and the Invisibles','Penny Balfour')
# actor('Oceans','Aldo Baglio')
# actor('A Sound of Thunder','Wilfried Hochholdinger')
# actor('Pompeii','Adewale Akinnuoye-Agbaje')
# actor('Top Cat Begins','Darin De Paul')
# actor('A Beautiful Mind','Christopher Plummer')
# actor('The Lion King','Jeremy Irons')
# actor('Journey 2: The Mysterious Island','Vanessa Hudgens')
# actor('Cloudy with a Chance of Meatballs 2','Will Forte')
# actor('Red Dragon','Harvey Keitel')
# actor('Hidalgo','Adam Alexi-Malle')
# actor('Jack and Jill','Eugenio Derbez')
# actor('2 Fast 2 Furious','Cole Hauser')
# actor('The Little Prince','Marion Cotillard')
# actor('The Invasion','Jeffrey Wright')
# actor('The Adventures of Rocky & Bullwinkle','Randy Quaid')
# actor('The Secret Life of Pets','Jenny Slate')
# actor('The League of Extraordinary Gentlemen','Stuart Townsend')
# actor('Despicable Me 2','Miranda Cosgrove')
# actor('Independence Day','Mary McDonnell')
# actor('The Lost World: Jurassic Park','Richard Attenborough')
# actor('Madagascar','Jada Pinkett Smith')
# actor('Children of Men','Charlie Hunnam')
# actor('X-Men','Halle Berry')
# actor('Wanted','Thomas Kretschmann')
# actor('The Rock','John Spencer')
# actor('Ice Age: The Meltdown','Queen Latifah')
# actor('50 First Dates','Sean Astin')
# actor('Hairspray','James Marsden')
# actor('Exorcist: The Beginning','Julian Wadham')
# actor('Inspector Gadget','Michelle Trachtenberg')
# actor('Now You See Me','Mélanie Laurent')
# actor('Grown Ups','Steve Buscemi')
# actor('The Terminal','Chi McBride')
# actor('Hotel for Dogs','Johnny Simmons')
# actor('Vertical Limit','Scott Glenn')
# actor('Charlie Wilsons War','Amy Adams')
# actor('Shark Tale','Jack Black')
# actor('Dreamgirls','Danny Glover')
# actor('Be Cool','Cedric the Entertainer')
# actor('Munich','Mathieu Kassovitz')
# actor('Tears of the Sun','Eamonn Walker')
# actor('Killers','Catherine O'Hara')
# actor('The Man from U.N.C.L.E.','Elizabeth Debicki')
# actor('Spanglish','Cloris Leachman')
# actor('Monster House','Sam Lerner')
# actor('Bandits','Troy Garity')
# actor('First Knight','Ben Cross')
# actor('Anna and the King','Tom Felton')
# actor('Immortals','Henry Cavill')
# actor('Hostage','Michelle Horn')
# actor('Titan A.E.','John Leguizamo')
# actor('Hollywood Homicide','Bruce Greenwood')
# actor('Soldier','Connie Nielsen')
# actor('Carriers','Emily VanCamp')
# actor('Monkeybone','Chris Kattan')
# actor('Flight of the Phoenix','Miranda Otto')
# actor('Unbreakable','Spencer Treat Clark')
# actor('Minions','Allison Janney')
# actor('Sucker Punch','Vanessa Hudgens')
# actor('Snake Eyes','Carla Gugino')
# actor('Sphere','Peter Coyote')
# actor('The Angry Birds Movie','Maya Rudolph')
# actor('Fools Gold','Ewen Bremner')
# actor('Funny People','Eric Bana')
# actor('The Kingdom','Jason Bateman')
# actor('Talladega Nights: The Ballad of Ricky Bobby','Gary Cole')
# actor('Dr. Dolittle 2','Kyla Pratt')
# actor('Braveheart','Patrick McGoohan')
# actor('Jarhead','Lucas Black')
# actor('The Simpsons Movie','Yeardley Smith')
# actor('The Majestic','David Ogden Stiers')
# actor('Driven','Estella Warren')
# actor('Two Brothers','Jaran 'See Tao' Petcharoen')
# actor('The Village','William Hurt')
# actor('Doctor Dolittle','Peter Boyle')
# actor('Signs','Abigail Breslin')
# actor('Shrek 2','Julie Andrews')
# actor('Cars','Larry the Cable Guy')
# actor('Runaway Bride','Rita Wilson')
# actor('xXx','Danny Trejo')
# actor('The SpongeBob Movie: Sponge Out of Water','Clancy Brown')
# actor('Ransom','Rene Russo')
# actor('Inglourious Basterds','Eli Roth')
# actor('Hook','Bob Hoskins')
# actor('Die Hard 2','Reginald VelJohnson')
# actor('S.W.A.T.','LL Cool J')
# actor('Vanilla Sky','Kurt Russell')
# actor('Lady in the Water','Sarita Choudhury')
# actor('AVP: Alien vs. Predator','Colin Salmon')
# actor('Alvin and the Chipmunks: The Squeakquel','Justin Long')
# actor('We Were Soldiers','Sam Elliott')
# actor('Olympus Has Fallen','Morgan Freeman')
# actor('Star Trek: Insurrection','LeVar Burton')
# actor('Battle: Los Angeles','Cory Hardrict')
# actor('Big Fish','Jessica Lange')
# actor('Wolf','Michelle Pfeiffer')
# actor('War Horse','Emily Watson')
# actor('The Monuments Men','Bill Murray')
# actor('The Abyss','Leo Burmester')
# actor('Wall Street: Money Never Sleeps','Carey Mulligan')
# actor('Dracula Untold','Art Parkinson')
# actor('The Siege','Tony Shalhoub')
# actor('Stardust','Robert De Niro')
# actor('Seven Years in Tibet','BD Wong')
# actor('The Dilemma','Jennifer Connelly')
# actor('Bad Company','Gabriel Macht')
# actor('Doom','Ben Daniels')
# actor('I Spy','Keith Dallas')
# actor('Underworld: Awakening','Theo James')
# actor('Rock of Ages','Alec Baldwin')
# actor('Harts War','Marcel Iureș')
# actor('Killer Elite','Dominic Purcell')
# actor('Rollerball','Naveen Andrews')
# actor('Ballistic: Ecks vs. Sever','Ray Park')
# actor('Hard Rain','Minnie Driver')
# actor('Osmosis Jones','Brandy Norwood')
# actor('Legends of Oz: Dorothys Return','Hugh Dancy')
# actor('Blackhat','Viola Davis')
# actor('Sky Captain and the World of Tomorrow','Angelina Jolie')
# actor('Basic Instinct 2','David Thewlis')
# actor('Escape Plan','Vinnie Jones')
# actor('The Legend of Hercules','Scott Adkins')
# actor('The Sum of All Fears','Ken Jenkins')
# actor('The Twilight Saga: Eclipse','Ashley Greene')
# actor('The Score','Angela Bassett')
# actor('Despicable Me','Julie Andrews')
# actor('Money Train','Robert Blake')
# actor('Ted 2','Jessica Barth')
# actor('Agora','Ashraf Barhom')
# actor('Mystery Men','William H. Macy')
# actor('Hall Pass','Christina Applegate')
# actor('The Insider','Diane Venora')
# actor('The Finest Hours','Eric Bana')
# actor('Body of Lies','Ali Suliman')
# actor('Dinner for Schmucks','Jemaine Clement')
# actor('Abraham Lincoln: Vampire Hunter','Mary Elizabeth Winstead')
# actor('Entrapment','Maury Chaykin')
# actor('The X Files','William B. Davis')
# actor('The Last Legion','Peter Mullan')
# actor('Saving Private Ryan','Tom Sizemore')
# actor('Need for Speed','Rami Malek')
# actor('What Women Want','Lauren Holly')
# actor('Ice Age','Goran Visnjic')
# actor('Dreamcatcher','Damian Lewis')
# actor('Lincoln','Joseph Gordon-Levitt')
# actor('The Matrix','Hugo Weaving')
# actor('Apollo 13','Gary Sinise')
# actor('The Santa Clause 2','Eric Lloyd')
# actor('Les Misérables','Amanda Seyfried')
# actor('Youve Got Mail','Greg Kinnear')
# actor('Step Brothers','Richard Jenkins')
# actor('The Mask of Zorro','Stuart Wilson')
# actor('Due Date','Jamie Foxx')
# actor('Unbroken','Miyavi')
# actor('Space Cowboys','James Garner')
# actor('Cliffhanger','Janine Turner')
# actor('Broken Arrow','Delroy Lindo')
# actor('The Kid','Lily Tomlin')
# actor('World Trade Center','Michael Peña')
# actor('Mona Lisa Smile','Maggie Gyllenhaal')
# actor('The Dictator','Megan Fox')
# actor('Eyes Wide Shut','Jackie Sawiris')
# actor('Annie','Cameron Diaz')
# actor('Focus','Robert Taylor')
# actor('This Means War','Laura Vandervoort')
# actor('Blade: Trinity','Jessica Biel')
# actor('Red Dawn','Darren Dalton')
# actor('Primary Colors','Kathy Bates')
# actor('Resident Evil: Retribution','Aryana Engineer')
# actor('Death Race','Tyrese Gibson')
# actor('The Long Kiss Goodnight','Craig Bierko')
# actor('Proof of Life','Pamela Reed')
# actor('Zathura: A Space Adventure','Kristen Stewart')
# actor('Fight Club','Jared Leto')
# actor('We Are Marshall','David Strathairn')
# actor('Hudson Hawk','James Coburn')
# actor('Lucky Numbers','Ed O'Neill')
# actor('I, Frankenstein','Jai Courtney')
# actor('Oliver Twist','Harry Eden')
# actor('Elektra','Cary-Hiroyuki Tagawa')
# actor('Sin City: A Dame to Kill For','Joseph Gordon-Levitt')
# actor('Random Hearts','Bonnie Hunt')
# actor('Everest','John Hawkes')
# actor('Perfume: The Story of a Murderer','Richard Felix')
# actor('Austin Powers in Goldmember','Michael York')
# actor('Astro Boy','Donald Sutherland')
# actor('Jurassic Park','Richard Attenborough')
# actor('Wyatt Earp','David Andrews')
# actor('Clear and Present Danger','Joaquim de Almeida')
# actor('Dragon Blade','Sharni Vinson')
# actor('Little Man','John Witherspoon')
# actor('U-571','Jon Bon Jovi')
# actor('The American President','Martin Sheen')
# actor('The Love Guru','Romany Malco')
# actor('3000 Miles to Graceland','Christian Slater')
# actor('The Hateful Eight','Walton Goggins')
# actor('Blades of Glory','Amy Poehler')
# actor('Hop','Hank Azaria')
# actor('300','David Wenham')
# actor('Meet the Fockers','Dustin Hoffman')
# actor('Marley & Me','Kathleen Turner')
# actor('The Green Mile','Bonnie Hunt')
# actor('Wild Hogs','William H. Macy')
# actor('Chicken Little','Steve Zahn')
# actor('Gone Girl','Neil Patrick Harris')
# actor('The Bourne Identity','Clive Owen')
# actor('GoldenEye','Famke Janssen')
# actor('The Generals Daughter','Timothy Hutton')
# actor('The Truman Show','Natascha McElhone')
# actor('The Prince of Egypt','Michelle Pfeiffer')
# actor('Daddy Day Care','Regina King')
# actor('2 Guns','Bill Paxton')
# actor('Cats & Dogs','Miriam Margolyes')
# actor('The Italian Job','Seth Green')
# actor('Two Weeks Notice','Dana Ivey')
# actor('Antz','Danny Glover')
# actor('Couples Retreat','Kristen Bell')
# actor('Days of Thunder','Randy Quaid')
# actor('Cheaper by the Dozen 2','Tom Welling')
# actor('Maze Runner: The Scorch Trials','Giancarlo Esposito')
# actor('Eat Pray Love','Billy Crudup')
# actor('The Family Man','Saul Rubinek')
# actor('RED','Mary-Louise Parker')
# actor('Any Given Sunday','James Woods')
# actor('The Horse Whisperer','Scarlett Johansson')
# actor('Collateral','Mark Ruffalo')
# actor('The Scorpion King','Steven Brand')
# actor('Ladder 49','Robert Patrick')
# actor('Jack Reacher','David Oyelowo')
# actor('Deep Blue Sea','Michael Rapaport')
# actor('This Is It','Dorian Holley')
# actor('Contagion','Jude Law')
# actor('Kangaroo Jack','Christopher Walken')
# actor('Coraline','Dawn French')
# actor('The Happening','Spencer Breslin')
# actor('Man on Fire','Radha Mitchell')
# actor('The Shaggy Dog','Spencer Breslin')
# actor('Starsky & Hutch','Fred Williamson')
# actor('Jingle All the Way','Rita Wilson')
# actor('Hellboy','John Hurt')
# actor('A Civil Action','William H. Macy')
# actor('ParaNorman','Anna Kendrick')
# actor('The Jackal','Diane Venora')
# actor('Paycheck','Paul Giamatti')
# actor('Up Close & Personal','Joe Mantegna')
# actor('The Tale of Despereaux','Tracey Ullman')
# actor('The Tuxedo','Debi Mazar')
# actor('Under Siege 2: Dark Territory','Katherine Heigl')
# actor('Jack Ryan: Shadow Recruit','Kenneth Branagh')
# actor('Joy','Dascha Polanco')
# actor('London Has Fallen','Angela Bassett')
# actor('Alien: Resurrection','Ron Perlman')
# actor('Shooter','Kate Mara')
# actor('The Boxtrolls','Dee Bradley Baker')
# actor('Practical Magic','Goran Visnjic')
# actor('The Lego Movie','Will Arnett')
# actor('Miss Congeniality 2: Armed and Fabulous','William Shatner')
# actor('Reign of Fire','Gerard Butler')
# actor('Gangster Squad','Emma Stone')
# actor('Year One','Oliver Platt')
# actor('Invictus','Patrick Mofokeng')
# actor('State of Play','Robin Wright')
# actor('Duplicity','Tom Wilkinson')
# actor('My Favorite Martian','Christopher Lloyd')
# actor('The Sentinel','Martin Donovan')
# actor('Planet 51','Justin Long')
# actor('Star Trek: Nemesis','LeVar Burton')
# actor('Intolerable Cruelty','Geoffrey Rush')
# actor('Trouble with the Curve','John Goodman')
# actor('Edge of Darkness','Shawn Roberts')
# actor('The Relic','James Whitmore')
# actor('Analyze That','Joe Viterelli')
# actor('Righteous Kill','Al Pacino')
# actor('Mercury Rising','Chi McBride')
# actor('The Soloist','Nelsan Ellis')
# actor('The Legend of Bagger Vance','Will Smith')
# actor('Almost Famous','Jason Lee')
# actor('Garfield: A Tail of Two Kitties','Ian Abercrombie')
# actor('xXx: State of the Union','Scott Speedman')
# actor('Priest','Maggie Q')
# actor('Sinbad: Legend of the Seven Seas','Joseph Fiennes')
# actor('Event Horizon','Joely Richardson')
# actor('Dragonfly','Susanna Thompson')
# actor('The Black Dahlia','Hilary Swank')
# actor('Flyboys','Philip Winchester')
# actor('The Last Castle','Steve Burton')
# actor('Supernova','Lou Diamond Phillips')
# actor('Winters Tale','William Hurt')
# actor('The Mortal Instruments: City of Bones','Jemima West')
# actor('Meet Dave','Scott Caan')
# actor('Dark Water','Dougray Scott')
# actor('Edtv','Jenna Elfman')
# actor('Inkheart','Eliza Bennett')
# actor('The Spirit','Eva Mendes')
# actor('Mortdecai','Paul Bettany')
# actor('In the Name of the King: A Dungeon Siege Tale','Leelee Sobieski')
# actor('Beyond Borders','Linus Roache')
# actor('The Monkey King 2','Xiao Shen Yang')
# actor('The Great Raid','Marton Csokas')
# actor('Deadpool','T.J. Miller')
# actor('Holy Man','Robert Loggia')
# actor('American Sniper','Cole Konis')
# actor('Goosebumps','Amy Ryan')
# actor('Just Like Heaven','Dina Spybey-Waters')
# actor('The Flintstones in Viva Rock Vegas','Jane Krakowski')
# actor('Rambo III','Spiros Focás')
# actor('Leatherheads','Wayne Duvall')
# actor('The Ridiculous 6','Terry Crews')
# actor('Did You Hear About the Morgans?','Sam Elliott')
# actor('The Internship','Max Minghella')
# actor('Resident Evil: Afterlife','Kim Coates')
# actor('Red Tails','Daniela Ruah')
# actor('The Devils Advocate','Jeffrey Jones')
# actor('Thats My Boy','Leighton Meester')
# actor('DragonHeart','Dina Meyer')
# actor('After the Sunset','Troy Garity')
# actor('Ghost Rider: Spirit of Vengeance','Fergus Riordan')
# actor('Captain Corellis Mandolin','Christian Bale')
# actor('The Pacifier','Chris Potter')
# actor('Walking Tall','Kristen Wilson')
# actor('Forrest Gump','Mykelti Williamson')
# actor('Alvin and the Chipmunks','Jane Lynch')
# actor('Meet the Parents','Blythe Danner')
# actor('Pocahontas','John Kassir')
# actor('Superman','Gene Hackman')
# actor('The Nutty Professor','Larry Miller')
# actor('Hitch','Amber Valletta')
# actor('George of the Jungle','John Cleese')
# actor('American Wedding','Eddie Kaye Thomas')
# actor('Captain Phillips','Chris Mulkey')
# actor('Date Night','Taraji P. Henson')
# actor('Casper','Eric Idle')
# actor('The Equalizer','David Harbour')
# actor('Maid in Manhattan','Stanley Tucci')
# actor('Crimson Tide','George Dzundza')
# actor('The Pursuit of Happyness','Brian Howe')
# actor('Flightplan','Kate Beahan')
# actor('Disclosure','Dylan Baker')
# actor('City of Angels','Dennis Franz')
# actor('Kill Bill: Vol. 1','Daryl Hannah')
# actor('Bowfinger','Christine Baranski')
# actor('Kill Bill: Vol. 2','Michael Madsen')
# actor('Tango & Cash','Jack Palance')
# actor('Death Becomes Her','Isabella Rossellini')
# actor('Shanghai Noon','Xander Berkeley')
# actor('Executive Decision','John Leguizamo')
# actor('Mr. Poppers Penguins','Angela Lansbury')
# actor('The Forbidden Kingdom','Liu Yifei')
# actor('Free Birds','George Takei')
# actor('Alien³','Pete Postlethwaite')
# actor('Evita','Jimmy Nail')
# actor('Ronin','Stellan Skarsgård')
# actor('The Ghost and the Darkness','John Kani')
# actor('Paddington','Michael Gambon')
# actor('The Watch','Richard Ayoade')
# actor('The Hunted','Leslie Stefanson')
# actor('Instinct','Maura Tierney')
# actor('Stuck on You','Wen Yann Shih')
# actor('Semi-Pro','David Koechner')
# actor('The Pirates! In an Adventure with Scientists!','Brian Blessed')
# actor('Changeling','Geoff Pierson')
# actor('Chain Reaction','Fred Ward')
# actor('The Fan','John Leguizamo')
# actor('The Phantom of the Opera','Miranda Richardson')
# actor('Elizabeth: The Golden Age','Laurence Fox')
# actor('Æon Flux','Sophie Okonedo')
# actor('Gods and Generals','Kevin Conway')
# actor('Turbulence','Héctor Elizondo')
# actor('Imagine That','Ronny Cox')
# actor('Muppets Most Wanted','Steve Whitmire')
# actor('Thunderbirds','Lou Hirsch')
# actor('Burlesque','Cam Gigandet')
# actor('A Very Long Engagement','Chantal Neuwirth')
# actor('Lolita','Peter Sellers')
# actor('D-Tox','Charles S. Dutton')
# actor('Blade II','Leonor Varela')
# actor('Seven Pounds','Woody Harrelson')
# actor('Bullet to the Head','Adewale Akinnuoye-Agbaje')
# actor('The Godfather: Part III','Talia Shire')
# actor('Elizabethtown','Alec Baldwin')
# actor('You, Me and Dupree','Michael Douglas')
# actor('Superman II','Jackie Cooper')
# actor('Gigli','Lainie Kazan')
# actor('All the Kings Men','James Gandolfini')
# actor('Shaft','Busta Rhymes')
# actor('Anastasia','Angela Lansbury')
# actor('Moulin Rouge!','Jim Broadbent')
# actor('Domestic Disturbance','Matt O'Leary')
# actor('Black Mass','Dakota Johnson')
# actor('Flags of Our Fathers','John Benjamin Hickey')
# actor('Law Abiding Citizen','Bruce McGill')
# actor('Grindhouse','Vanessa Ferlito')
# actor('Beloved','Lisa Gay Hamilton')
# actor('Lucky You','Debra Messing')
# actor('Catch Me If You Can','Martin Sheen')
# actor('Zero Dark Thirty','Joel Edgerton')
# actor('The Break-Up','Cole Hauser')
# actor('Mamma Mia!','Colin Firth')
# actor('Valentines Day','Eric Dane')
# actor('The Dukes of Hazzard','Willie Nelson')
# actor('The Thin Red Line','Ben Chaplin')
# actor('The Change-Up','Leslie Mann')
# actor('Man on the Moon','Danny DeVito')
# actor('Casino','James Woods')
# actor('From Paris with Love','Richard Durden')
# actor('Bulletproof Monk','Chow Yun-fat')
# actor('Me, Myself & Irene','Robert Forster')
# actor('Barnyard','Danny Glover')
# actor('Deck the Halls','Kristin Chenoweth')
# actor('The Twilight Saga: New Moon','Billy Burke')
# actor('Shrek','John Lithgow')
# actor('The Adjustment Bureau','Anthony Mackie')
# actor('Robin Hood: Prince of Thieves','Mary Elizabeth Mastrantonio')
# actor('Jerry Maguire','Kelly Preston')
# actor('Ted','Joel McHale')
# actor('As Good as It Gets','Cuba Gooding Jr.')
# actor('Patch Adams','Peter Coyote')
# actor('Anchorman 2: The Legend Continues','Christina Applegate')
# actor('Mr. Deeds','Allen Covert')
# actor('Super 8','Kyle Chandler')
# actor('Erin Brockovich','Marg Helgenberger')
# actor('How to Lose a Guy in 10 Days','Annie Parisse')
# actor('22 Jump Street','Ice Cube')
# actor('Interview with the Vampire','Antonio Banderas')
# actor('Yes Man','Sasha Alexander')
# actor('Central Intelligence','Aaron Paul')
# actor('Stepmom','Jena Malone')
# actor('Daddys Home','Thomas Haden Church')
# actor('Into the Woods','Anna Kendrick')
# actor('Inside Man','Christopher Plummer')
# actor('Payback','Maria Bello')
# actor('Congo','Tim Curry')
# actor('We Bought a Zoo','Colin Ford')
# actor('Knowing','Ben Mendelsohn')
# actor('Failure to Launch','Justin Bartha')
# actor('The Ring Two','David Dorfman')
# actor('Crazy, Stupid, Love.','Emma Stone')
# actor('Garfield','Stephen Tobolowsky')
# actor('Christmas with the Kranks','M. Emmet Walsh')
# actor('Moneyball','Robin Wright')
# actor('Outbreak','Kevin Spacey')
# actor('Non-Stop','Michelle Dockery')
# actor('Race to Witch Mountain','Carla Gugino')
# actor('V for Vendetta','Stephen Fry')
# actor('Shanghai Knights','Aaron Taylor-Johnson')
# actor('Curious George','Eugene Levy')
# actor('Herbie Fully Loaded','Breckin Meyer')
# actor('Dont Say a Word','Skye McCole Bartusiak')
# actor('Hansel & Gretel: Witch Hunters','Pihla Viitala')
# actor('Unfaithful','Erik Per Sullivan')
# actor('I Am Number Four','Dianna Agron')
# actor('Syriana','Chris Cooper')
# actor('13 Hours: The Secret Soldiers of Benghazi','Pablo Schreiber')
# actor('The Book of Life','Christina Applegate')
# actor('Firewall','Carly Schroeder')
# actor('Absolute Power','Scott Glenn')
# actor('G.I. Jane','Jason Beghe')
# actor('The Game','James Rebhorn')
# actor('Silent Hill','Deborah Kara Unger')
# actor('The Replacements','Orlando Jones')
# actor('American Reunion','Chris Klein')
# actor('The Negotiator','Ron Rifkin')
# actor('Into the Storm','Nathan Kress')
# actor('Beverly Hills Cop III','Gilbert R. Hill')
# actor('Gremlins 2: The New Batch','Robert Prosky')
# actor('The Judge','Vincent D'Onofrio')
# actor('The Peacemaker','Goran Visnjic')
# actor('Resident Evil: Apocalypse','Thomas Kretschmann')
# actor('Bridget Jones: The Edge of Reason','Jim Broadbent')
# actor('Out of Time','John Billingsley')
# actor('On Deadly Ground','John C. McGinley')
# actor('The Adventures of Sharkboy and Lavagirl','David Arquette')
# actor('The Beach','Virginie Ledoyen')
# actor('Raising Helen','Hayden Panettiere')
# actor('Ninja Assassin','Randall Duk Kim')
# actor('For Love of the Game','Jena Malone')
# actor('Striptease','Ving Rhames')
# actor('Marmaduke','Christopher Mintz-Plasse')
# actor('Hereafter','Thierry Neuvic')
# actor('Murder by Numbers','Michael Pitt')
# actor('Assassins','Anatoli Davydov')
# actor('Hannibal Rising','Dominic West')
# actor('The Story of Us','Colleen Rennison')
# actor('The Host','William Hurt')
# actor('Basic','Giovanni Ribisi')
# actor('Blood Work','Wanda De Jesus')
# actor('The International','Ulrich Thomsen')
# actor('Escape from L.A.','Pam Grier')
# actor('The Iron Giant','Christopher McDonald')
# actor('The Life Aquatic with Steve Zissou','Willem Dafoe')
# actor('Free State of Jones','Keri Russell')
# actor('The Life of David Gale','Gabriel Mann')
# actor('Man of the House','Paula Garcés')
# actor('Run All Night','Boyd Holbrook')
# actor('Eastern Promises','Armin Mueller-Stahl')
# actor('Into the Blue','Ashley Scott')
# actor('The Messenger: The Story of Joan of Arc','John Malkovich')
# actor('Your Highness','Zooey Deschanel')
# actor('Dream House','Marton Csokas')
# actor('Mad City','Alan Alda')
# actor('Babys Day Out','Brian Haley')
# actor('The Scarlet Letter','Robert Prosky')
# actor('Fair Game','Brooke Smith')
# actor('Domino','Delroy Lindo')
# actor('Jade','Michael Biehn')
# actor('Gamer','Amber Valletta')
# actor('Beautiful Creatures','Viola Davis')
# actor('Death to Smoochy','Danny DeVito')
# actor('Zoolander 2','Penélope Cruz')
# actor('The Big Bounce','Sara Foster')
# actor('What Planet Are You From?','Greg Kinnear')
# actor('Drive Angry','Billy Burke')
# actor('Street Fighter: The Legend of Chun-Li','Michael Clarke Duncan')
# actor('The One','Delroy Lindo')
# actor('The Adventures of Ford Fairlane','Morris Day')
# actor('The Boat That Rocked','Bill Nighy')
# actor('Traffic','Tomás Milián')
# actor('Indiana Jones and the Last Crusade','Alison Doody')
# actor('Anna Karenina','Kelly Macdonald')
# actor('Chappie','Yolandi Visser')
# actor('The Bone Collector','Michael Rooker')
# actor('Panic Room','Dwight Yoakam')
# actor('The Tooth Fairy','Jianna Ballard')
# actor('Three Kings','Spike Jonze')
# actor('Child 44','Joel Kinnaman')
# actor('Rat Race','Breckin Meyer')
# actor('K-PAX','Alfre Woodard')
# actor('Kate & Leopold','Breckin Meyer')
# actor('Bedazzled','Orlando Jones')
# actor('The Cotton Club','Lonette McKee')
# actor('3:10 to Yuma','Dallas Roberts')
# actor('Taken 3','Famke Janssen')
# actor('Out of Sight','Don Cheadle')
# actor('The Cable Guy','Jack Black')
# actor('Earth','Kitu Gidwani')
# actor('Dick Tracy','Charlie Korsmo')
# actor('The Thomas Crown Affair','Ben Gazzara')
# actor('Riding in Cars with Boys','Brittany Murphy')
# actor('First Blood','Bill McKinney')
# actor('Solaris','Anatoliy Solonitsyn')
# actor('Happily NEver After','Lisa Kaplan')
# actor('Mary Reilly','Michael Gambon')
# actor('My Best Friends Wedding','Rupert Everett')
# actor('Americas Sweethearts','John Cusack')
# actor('Insomnia','Maura Tierney')
# actor('Star Trek: First Contact','LeVar Burton')
# actor('Jonah Hex','Michael Fassbender')
# actor('Courage Under Fire','Matt Damon')
# actor('Liar Liar','Jennifer Tilly')
# actor('The Infiltrator','Daniel Mays')
# actor('Inchon','Toshirō Mifune')
# actor('The Flintstones','Rosie O'Donnell')
# actor('Taken 2','Rade Serbedzija')
# actor('Scary Movie 3','Charlie Sheen')
# actor('Miss Congeniality','Candice Bergen')
# actor('Journey to the Center of the Earth','Seth Meyers')
# actor('The Princess Diaries 2: Royal Engagement','John Rhys-Davies')
# actor('The Pelican Brief','William Atherton')
# actor('The Client','Anthony LaPaglia')
# actor('The Bucket List','Beverly Todd')
# actor('Patriot Games','Thora Birch')
# actor('Monster-in-Law','Wanda Sykes')
# actor('Prisoners','Maria Bello')
# actor('Training Day','Tom Berenger')
# actor('Galaxy Quest','Tony Shalhoub')
# actor('Scary Movie 2','Shawn Wayans')
# actor('The Muppets','John Krasinski')
# actor('Blade','N'Bushe Wright')
# actor('Coach Carter','Rick Gonzalez')
# actor('Changing Lanes','Toni Collette')
# actor('Anaconda','Eric Stoltz')
# actor('Coyote Ugly','Izabella Miko')
# actor('Love Actually','Laura Linney')
# actor('A Bugs Life','Phyllis Diller')
# actor('From Hell','Robbie Coltrane')
# actor('The Specialist','Rod Steiger')
# actor('Tin Cup','George Perez')
# actor('Yours, Mine and Ours','Tom Bosley')
# actor('Kicking & Screaming','Musetta Vander')
# actor('The Hitchhikers Guide to the Galaxy','Yasiin Bey')
# actor('Fat Albert','Keith Robinson')
# actor('Resident Evil: Extinction','Iain Glen')
# actor('Blended','Bella Thorne')
# actor('Last Holiday','Giancarlo Esposito')
# actor('The River Wild','Benjamin Bratt')
# actor('The Indian in the Cupboard','Richard Jenkins')
# actor('Savages','Benicio del Toro')
# actor('Cellular','Jessica Biel')
# actor('Johnny English','Tasha de Vasconcelos')
# actor('The Ant Bully','Paul Giamatti')
# actor('Dune','Brad Dourif')
# actor('Across the Universe','Dana Fuchs')
# actor('Revolutionary Road','Kathryn Hahn')
# actor('16 Blocks','Jenna Stern')
# actor('Babylon A.D.','Lambert Wilson')
# actor('The Glimmer Man','Brian Cox')
# actor('Multiplicity','Eugene Levy')
# actor('Aliens in the Attic','Robert Hoffman')
# actor('The Pledge','Robin Wright')
# actor('The Producers','Eileen Essell')
# actor('The Phantom','Catherine Zeta-Jones')
# actor('All the Pretty Horses','Sam Shepard')
# actor('Nixon','Ed Harris')
# actor('The Ghost Writer','Kim Cattrall')
# actor('Deep Rising','Kevin J. O'Connor')
# actor('Miracle at St. Anna','John Turturro')
# actor('Curse of the Golden Flower','Liu Ye')
# actor('Bangkok Dangerous','Panward Hemmanee')
# actor('Big Trouble','Ben Foster')
# actor('Love in the Time of Cholera','Catalina Sandino Moreno')
# actor('Shadow Conspiracy','Stephen Lang')
# actor('Johnny English Reborn','Rosamund Pike')
# actor('Foodfight!','Eva Longoria')
# actor('Argo','John Goodman')
# actor('The Fugitive','Julianne Moore')
# actor('The Bounty Hunter','Siobhan Fallon')
# actor('Sleepers','Jason Patric')
# actor('Rambo: First Blood Part II','Steven Berkoff')
# actor('The Juror','Anne Heche')
# actor('Pinocchio','Marion Darlington')
# actor('Heavens Gate','Isabelle Huppert')
# actor('Underworld: Evolution','Shane Brolly')
# actor('Victor Frankenstein','Andrew Scott')
# actor('Finding Forrester','Anna Paquin')
# actor('28 Days','Elizabeth Perkins')
# actor('Unleashed','Vincent Regan')
# actor('The Sweetest Thing','Selma Blair')
# actor('The Firm','Holly Hunter')
# actor('Charlie St. Cloud','Augustus Prew')
# actor('The Mechanic','Mini Anden')
# actor('21 Jump Street','Dave Franco')
# actor('Notting Hill','Tim McInnerny')
# actor('Chicken Run','Imelda Staunton')
# actor('Along Came Polly','Debra Messing')
# actor('Boomerang','David Alan Grier')
# actor('The Heat','Michael Rapaport')
# actor('Cleopatra','Roddy McDowall')
# actor('Here Comes the Boom','Joe Rogan')
# actor('High Crimes','Amanda Peet')
# actor('The Mirror Has Two Faces','George Segal')
# actor('The Mothman Prophecies','Bob Tracey')
# actor('Brüno','Gustaf Hammarsten')
# actor('Licence to Kill','Talisa Soto')
# actor('Red Riding Hood','Shiloh Fernandez')
# actor('15 Minutes','Kelsey Grammer')
# actor('Super Mario Bros.','Samantha Mathis')
# actor('Lord of War','Ethan Hawke')
# actor('Hero','Donnie Yen')
# actor('One for the Money','John Leguizamo')
# actor('The Interview','Randall Park')
# actor('The Warriors Way','Danny Huston')
# actor('Micmacs','Jean-Pierre Marielle')
# actor('8 Mile','Kim Basinger')
# actor('Why I Did (Not) Eat My Father','Patrice Thibaud')
# actor('A Knights Tale','Paul Bettany')
# actor('The Medallion','Julian Sands')
# actor('The Sixth Sense','Haley Joel Osment')
# actor('Man on a Ledge','Ed Harris')
# actor('The Big Year','Rashida Jones')
# actor('The Karate Kid','Martin Kove')
# ...
# actor('The Partys Over','Louise Sorel')
# actor('Proud','UNK')
# actor('The Poker House','Chloë Grace Moretz')
# actor('Childless','James Naughton')
# actor('ZMD: Zombies of Mass Destruction','Bill Johns')
# actor('Snow White: A Deadly Summer','Tim Abell')
# actor('Hidden Away','Alex Angulo')
# actor('My Last Day Without You','Marlene Forte')
# actor('Steppin: The Movie','UNK')
# actor('Doc Hollidays Revenge','Bart Voitila')
# actor('Black Rock','Katie Aselton')
# actor('Truth or Dare','David Oakes')
# actor('The Pet','Lydia McLane')
# actor('Bang Bang Baby','David Reale')
# actor('Fear Clinic','Fiona Dourif')
# actor('Zombie Hunter','Terry Guthrie')
# actor('A Fine Step','UNK')
# actor('Charly','Leon Janney')
# actor('Banshee Chapter','Monique Candelaria')
# actor('Ask Me Anything','Martin Sheen')
# actor('And Then Came Love','Eartha Kitt')
# actor('Food Chains','UNK')
# actor('On the Waterfront','Rod Steiger')
# actor('L!fe Happens','Geoff Stults')
# actor('4 Months, 3 Weeks and 2 Days','Alexandru Potocean')
# actor('The Horror Network Vol. 1','Brian Dorton')
# actor('Hard Candy','Odessa Rae')
# actor('The Quiet','Martin Donovan')
# actor('Circumstance','Soheil Parsa')
# actor('Fruitvale Station','Ahna O'Reilly')
# actor('The Brass Teapot','Billy Magnussen')
# actor('Bambi','Cammie King')
# actor('The Hammer','Christopher Darga')
# actor('Latter Days','Joseph Gordon-Levitt')
# actor('Elza','UNK')
# actor('1982','Quinton Aaron')
# actor('For a Good Time, Call...','Justin Long')
# actor('Celeste & Jesse Forever','Emma Roberts')
# actor('Time Changer','Jennifer O'Neill')
# actor('London to Brighton','Lorraine Stanley')
# actor('American Hero','Jonathan Billions')
# actor('Windsor Drive','Kyan DuBois')
# actor('A Separation','پیمان معادی')
# actor('Crying with Laughter','Jo Hartley')
# actor('Welcome to the Dollhouse','Christina Vidal')
# actor('Ruby in Paradise','Dorothy Lyman')
# actor('Raising Victor Vargas','Altagracia Guzman')
# actor('Pandoras Box','Carl Goetz')
# actor('Harrison Montgomery','UNK')
# actor('Live-In Maid','Claudia Lapacó')
# actor('Deterrence','Clotilde Courau')
# actor('The Mudge Boy','Pablo Schreiber')
# actor('The Young Unknowns','Leslie Bibb')
# actor('Not Cool','Michelle Veintimilla')
# actor('Dead Snow','Jeppe Beck Laursen')
# actor('Saints and Soldiers','Corbin Allred')
# actor('Vessel','Walter Phelan')
# actor('American Graffiti','Charles Martin Smith')
# actor('Iraq for Sale: The War Profiteers','UNK')
# actor('Aqua Teen Hunger Force Colon Movie Film for Theaters','Andy Merrill')
# actor('Safety Not Guaranteed','Karan Soni')
# actor('Kevin Hart: Laugh at My Pain','UNK')
# actor('Kill List','Michael Smiley')
# actor('The Innkeepers','George Riddle')
# actor('The Conformist','Dominique Sanda')
# actor('Interview with the Assassin','Raymond J. Barry')
# actor('Donkey Punch','Robert Boulter')
# actor('All the Boys Love Mandy Lane','Whitney Able')
# actor('Bled','Michele Morrow')
# actor('High Noon','Lloyd Bridges')
# actor('Hoop Dreams','UNK')
# actor('Rize','Dragon')
# actor('L.I.E.','Billy Kay')
# actor('The Sisterhood of Night','Laura Fraser')
# actor('B-Girl','Drew Sidora')
# actor('Half Nelson','Nathan Corbett')
# actor('Naturally Native','Kimberly Guerrero')
# actor('Hav Plenty','Robinne Lee')
# actor('Adulterers','Stephanie Charles')
# actor('Escape from Tomorrow','Danielle Safady')
# actor('Starsuckers','Josef d'Bache-Kane')
# actor('The Hadza:  Last of the First','UNK')
# actor('After','Ric Reitz')
# actor('Treachery','Caitlin Keats')
# actor('Walter','William H. Macy')
# actor('Top Hat','Helen Broderick')
# actor('The Blair Witch Project','Bob Griffith')
# actor('Woodstock','Arlo Guthrie')
# actor('The Kentucky Fried Movie','Saul Kahan')
# actor('Mercy Streets','Lawrence Taylor')
# actor('Carousel of Revenge','Ben Coler')
# actor('Broken Vessels','Susan Traylor')
# actor('Water & Power','Yvette Yates')
# actor('They Will Have to Kill Us First','Nathanael Dembélé')
# actor('Light from the Darkroom','UNK')
# actor('The Country Doctor','Félix Moati')
# actor('The Maids Room','Philip Ettinger')
# actor('A Hard Days Night','Ringo Starr')
# actor('The Harvest (La Cosecha)','UNK')
# actor('Love Letters','James Keach')
# actor('Juliet and Alfa Romeo','Katja Škofić')
# actor('Fireproof','Stephen Dervan')
# actor('Faith Connections','Baby Bajrangi')
# actor('Benji','Peter Breck')
# actor('Open Water','Michael E. Williamson')
# actor('High Road','Andrew Daly')
# actor('Kingdom of the Spiders','Lieux Dressler')
# actor('Mad Hot Ballroom','UNK')
# actor('The Station Agent','Michelle Williams')
# actor('To Save A Life','Steven Crowder')
# actor('Wordplay','Trip Payne')
# actor('Beyond the Mat','Dwayne Johnson')
# actor('The Singles Ward','Michael Birkeland')
# actor('Osama','Mohammad Nadir Khwaja')
# actor('Sholem Aleichem: Laughing In The Darkness','Dan Miron')
# actor('Groove','Lola Glaudini')
# actor('The R.M.','UNK')
# actor('Twin Falls Idaho','Jon Gries')
# actor('Mean Creek','Josh Peck')
# actor('Hurricane Streets','Carlo Alban')
# actor('Never Again','Bill Duke')
# actor('Civil Brand','Clifton Powell')
# actor('Lonesome Jim','Mary Kay Place')
# actor('Drinking Buddies','Ron Livingston')
# actor('Deceptive Practice: The Mysteries and Mentors of Ricky Jay','David Mamet')
# actor('Seven Samurai','Seiji Miyaguchi')
# actor('The Other Dream Team','Dan Majerle')
# actor('Johnny Suede','Nick Cave')
# actor('Finishing The Game','Meredith Scott Lynn')
# actor('Rubber','Roxane Mesquida')
# actor('Kiss the Bride','UNK')
# actor('The Slaughter Rule','Amy Adams')
# actor('Monsters','Kevon Kane')
# actor('The Californians','Cloris Leachman')
# actor('The Living Wake','Ann Dowd')
# actor('Detention of the Dead','Jayson Blair')
# actor('Crazy Stone','Xu Zheng')
# actor('Scott Walker: 30 Century Man','Jarvis Cocker')
# actor('Everything Put Together','Jacqueline Heinze')
# actor('Good Kill','Jake Abel')
# actor('The Outrageous Sophie Tucker','UNK')
# actor('Now Is Good','Olivia Williams')
# actor('Girls Gone Dead','Caley Hayes')
# actor('America Is Still the Place','UNK')
# actor('Subconscious','Tom Stedham')
# actor('Enter Nowhere','Shaun Sipos')
# actor('El Rey de Najayo','Juan Maria Almonte')
# actor('Fight to the Finish','Anna Ross')
# actor('Alleluia! The Devils Carnival','Emilie Autumn')
# actor('The Sound and the Shadow','Mary Kate Wiles')
# actor('Rodeo Girl','Carrie Bradstreet')
# actor('Born to Fly: Elizabeth Streb vs. Gravity','Jaclyn Carlson')
# actor('The Little Ponderosa Zoo','UNK')
# actor('The Toxic Avenger','Cindy Manion')
# actor('Straight Out of Brooklyn','UNK')
# actor('Bloody Sunday','Mary Moulds')
# actor('Diamond Ruff','UNK')
# actor('Conversations with Other Women','Brian Geraghty')
# actor('Poultrygeist: Night of the Chicken Dead','Robin L. Watkins')
# actor('Mutual Friends','Michael Stahl-David')
# actor('42nd Street','Ruby Keeler')
# actor('Rise of the Entrepreneur: The Search for a Better Way','UNK')
# actor('Metropolitan','Carolyn Farina')
# actor('As It Is in Heaven','Lennart Jähkel')
# actor('Roadside','UNK')
# actor('Napoleon Dynamite','Efren Ramirez')
# actor('Blue Ruin','Kevin Kolack')
# actor('Paranormal Activity','Amber Armstrong')
# actor('Dogtown and Z-Boys','Steve Caballero')
# actor('Monty Python and the Holy Grail','Eric Idle')
# actor('Quinceañera','David W. Ross')
# actor('Gory Gory Hallelujah','UNK')
# actor('Tarnation','Rosemary Davis')
# actor('I Want Your Money','UNK')
# actor('Love in the Time of Monsters','Marissa Skell')
# actor('The Beyond','Antoine Saint-John')
# actor('What Happens in Vegas','Queen Latifah')
# actor('The Dark Hours','Iris Graham')
# actor('My Beautiful Laundrette','Saeed Jaffrey')
# actor('Fabled','UNK')
# actor('Show Me','Gabriel Hogan')
# actor('Cries and Whispers','Liv Ullmann')
# actor('Intolerance','F.A. Turner')
# actor('Trekkies','James Doohan')
# actor('The Broadway Melody','Nacio Herb Brown')
# actor('The Evil Dead','Betsy Baker')
# actor('Maniac','Zoe Aggeliki')
# actor('Censored Voices','UNK')
# actor('Murderball','Scott Hogsett')
# actor('American Ninja 2: The Confrontation','Gary Conway')
# actor('51 Birch Street','UNK')
# actor('Rotor DR1','Steve Moses')
# actor('12 Angry Men','Lee J. Cobb')
# actor('My Dog Tulip','Peter Gerety')
# actor('It Happened One Night','Roscoe Karns')
# actor('Dogtooth','Christos Stergioglou')
# actor('Tupac: Resurrection','UNK')
# actor('Tumbleweeds','UNK')
# actor('The Prophecy','Eric Stoltz')
# actor('When the Cats Away','Olivier Py')
# actor('Pieces of April','Oliver Platt')
# actor('The Big Swap','Jackie Sawiris')
# actor('Old Joy','Robin Rosenberg')
# actor('Wendy and Lucy','John Robinson')
# actor('3 Backyards','Rachel Resheff')
# actor('Pierrot le Fou','Dirk Sanders')
# actor('Sisters in Law','UNK')
# actor('Ayurveda: Art of Being','UNK')
# actor('Nothing But a Man','Gloria Foster')
# actor('First Love, Last Rites','Robert John Burke')
# actor('Fighting Tommy Riley','Diane Tayler')
# actor('Royal Kill','Lalaine')
# actor('The Looking Glass','Harry Musselwhite')
# actor('Death Race 2000','Mary Woronov')
# actor('Locker 13','Jason Marsden')
# actor('Midnight Cabaret','Laura Harrington')
# actor('Andersons Cross','Jerome Elston Scott')
# actor('Bizarre','Rebekah Underhill')
# actor('Graduation Day','E. Danny Murphy')
# actor('Some Guy Who Kills People','Leo Fitzpatrick')
# actor('Compliance','Philip Ettinger')
# actor('Chasing Amy','Dwight Ewell')
# actor('Lovely & Amazing','Jake Gyllenhaal')
# actor('Death Calls','UNK')
# actor('Better Luck Tomorrow','Karin Anna Cheung')
# actor('The Incredibly True Adventure of Two Girls In Love','Nicole Ari Parker')
# actor('Chuck & Buck','Maya Rudolph')
# actor('American Desi','Ronobir Lahiri')
# actor('Amidst the Devils Wings','UNK')
# actor('Cube','Andrew Miller')
# actor('Love and Other Catastrophes','Frances O'Connor')
# actor('I Married a Strange Person!','UNK')
# actor('November','Nora Dunn')
# actor('Like Crazy','Charlie Bewley')
# actor('Teeth and Blood','Greg Eagles')
# actor('Sugar Town','Jade Gordon')
# actor('The Motel','Samantha Futerman')
# actor('The Canyons','Nolan Gerard Funk')
# actor('On the Outs','Dominic Colón')
# actor('Shotgun Stories','Douglas Ligon')
# actor('Exam','Gemma Chan')
# actor('The Sticky Fingers of Time','James Urbaniak')
# actor('Sunday School Musical','Robert Acinapura')
# actor('Rust','Audrey Lynn Tennent')
# actor('Ink','Jeremy Make')
# actor('The Christmas Bunny','Florence Henderson')
# actor('Butterfly','Ed McMahon')
# actor('UnDivided','UNK')
# actor('The Frozen','UNK')
# actor('Horse Camp','Dana Blackstone')
# actor('Give Me Shelter','Alison Eastwood')
# actor('The Big Parade','Claire McDowell')
# actor('Little Big Top','Jacob Zachar')
# actor('Along the Roadside','UNK')
# actor('Bronson','Kelly Adams')
# actor('Western Religion','Miles Szanto')
# actor('Burn','UNK')
# actor('Urbania','Lothaire Bluteau')
# actor('The Stewardesses','Anita de Moulin')
# actor('The Beast from 20,000 Fathoms','Kenneth Tobey')
# actor('Mad Max','Steve Bisley')
# actor('Swingers','Patrick Van Horn')
# actor('A Fistful of Dollars','Wolfgang Lukschy')
# actor('She Done Him Wrong','Gilbert Roland')
# actor('Short Cut to Nirvana: Kumbh Mela','UNK')
# actor('The Grace Card','Cindy Hodge')
# actor('Middle of Nowhere','Emayatzy Corinealdi')
# actor('Three','Annedore Kleist')
# actor('The Business of Fancydancing','Swil Kanim')
# actor('Call + Response','UNK')
# actor('Malevolence','R. Brandon Johnson')
# actor('Reality Show','Scott Anderson')
# actor('Super Hybrid','Adrien Dorval')
# actor('Baghead','Elise Muller')
# actor('American Beast','Taylor Scott Olson')
# actor('The Case of the Grinning Cat','UNK')
# actor('Ordet','Emil Hass Christensen')
# actor('Good Dick','Martin Starr')
# actor('The Man from Earth','Ellen Crawford')
# actor('The Trials Of Darryl Hunt','UNK')
# actor('Samantha: An American Girl Holiday','Kelsey Lewis')
# actor('Yesterday Was a Lie','Mik Scriba')
# actor('Theresa Is a Mother','Robert Turano')
# actor('H.','Julian Gamble')
# actor('Archaeology of a Woman','Karl Geary')
# actor('Children of Heaven','UNK')
# actor('Weekend','Laura Freeman')
# actor('Shes Gotta Have It','Spike Lee')
# actor('Butterfly Girl','UNK')
# actor('The World Is Mine','Ana Vatamanu')
# actor('Another Earth','DJ Flava')
# actor('Sweet Sweetbacks Baadasssss Song','Mario Van Peebles')
# actor('Perfect Cowboy','Sharon Bollum')
# actor('Tadpole','John Ritter')
# actor('Once','Gerard Hendrick')
# actor('The Woman Chaser','Emily Newman')
# actor('The Horse Boy','Rowan Isaacson')
# actor('When the Lights Went Out','Steven Waddington')
# actor('Heroes of Dirt','UNK')
# actor('A Charlie Brown Christmas','Bill Melendez')
# actor('Antarctic Edge: 70° South','UNK')
# actor('Aroused','Katsuni')
# actor('Top Spin','UNK')
# actor('Roger & Me','Fred Ross')
# actor('An American in Hollywood','Richard Carroll Jr.')
# actor('Sound of My Voice','Davenia McFadden')
# actor('The Blood of My Brother: A Story of Death in Iraq','UNK')
# actor('Your Sisters Sister','Mike Birbiglia')
# actor('A Dogs Breakfast','Christopher Judge')
# actor('The Married Woman','Christophe Bourseiller')
# actor('The Birth of a Nation','Jackie Earle Haley')
# actor('The Work and The Story','UNK')
# actor('Facing the Giants','Chris WIllis')
# actor('The Gallows','Reese Mishler')
# actor('Eraserhead','Jeanne Bates')
# actor('Hollywood Shuffle','Starletta DuPois')
# actor('The Mighty','Gena Rowlands')
# actor('Penitentiary','Hazel Spears ')
# actor('The Lost Skeleton of Cadavra','Brian Howe')
# actor('Dude Wheres My Dog?','Kevin Farley')
# actor('Cheap Thrills','David Koechner')
# actor('Indie Game: The Movie','Tommy Refenes')
# actor('Straightheads','Antony Byrne')
# actor('Open Secret','Roman Bohnen')
# actor('Echo Dr.','Claire Gordon-Harper')
# actor('The Night Visitor','Per Oscarsson')
# actor('The Past Is a Grotesque Animal','Kevin Barnes')
# actor('Peace, Propaganda & the Promised Land','UNK')
# actor('Pi','Samia Shoaib')
# actor('I Love You, Dont Touch Me!','Meredith Scott Lynn')
# actor('20 Dates','Richard Arlook')
# actor('Queen Crab','Steve Diasparra')
# actor('Super Size Me','Stephen Siegel')
# actor('The FP','Caitlyn Folley')
# actor('Happy Christmas','Lena Dunham')
# actor('The Brain That Wouldnt Die','Audrey Devereal')
# actor('Tiger Orange','Darryl Stephens')
# actor('Supporting Characters','Melonie Diaz')
# actor('Absentia','Dave Levine')
# actor('The Brothers McMullen','Connie Britton')
# actor('The Dirties','Brandon Wickens')
# actor('Gabriela','Paulo Goulart')
# actor('Tiny Furniture','Rachel Howe')
# actor('Hayride','Jeremy Sande')
# actor('The Naked Ape','Amanda MacDonald')
# actor('Counting','UNK')
# actor('The Call of Cthulhu','Chad Fifer')
# actor('Bending Steel','UNK')
# actor('The Signal','Laurence Fishburne')
# actor('The Image Revolution','Marc Silvestri')
# actor('This Is Martin Bonner','Robert Longstreet')
# actor('A True Story','Cameron Fife')
# actor('George Washington','Curtis Cotton III')
# actor('Smiling Fish & Goat On Fire','UNK')
# actor('Dawn of the Crescent Moon','Brandon Smith')
# actor('Raymond Did It','Steven Lee Edwards')
# actor('The Last Waltz','Richard Manuel')
# actor('Run, Hide, Die','Tabitha Bastien')
# actor('The Exploding Girl','Hunter Canning')
# actor('The Legend of Gods Gun','Julie Patterson')
# actor('Mutual Appreciation','UNK')
# actor('Her Cry: La Llorona Investigation','Parker Riggs')
# actor('Down Terrace','David Schaal')
# actor('Clerks','Kevin Smith')
# actor('Pink Narcissus','UNK')
# actor('Funny Ha Ha','Jennifer L. Schaper')
# actor('In the Company of Men','Michael Martin')
# actor('Manito','Jessica Morales')
# actor('Rampage','Lynda Boyd')
# actor('Slacker','UNK')
# actor('Dutch Kills','Celestine Rae')
# actor('Dry Spell','Rachael Robbins')
# actor('Flywheel','UNK')
# actor('Backmask','Gage Golightly')
# actor('The Puffy Chair','UNK')
# actor('Stories of Our Lives','Kelly Gichohi')
# actor('Breaking Upwards','Andrea Martin')
# actor('All Superheroes Must Die','Sophie Merkley')
# actor('Pink Flamingos','Mink Stole')
# actor('Clean','Jeanne Balibar')
# actor('The Circle','Elham Saboktakin')
# actor('Tin Can Man','Kreeta Taponen')
# actor('Cure','Anna Nakagawa')
# actor('On The Downlow','Felipe Camacho')
# actor('Sanctuary: Quite a Conundrum','Anthony Rutowicz')
# actor('Bang','Erik Schrody')
# actor('Primer','Anand Upadhyaya')
# actor('Cavite','UNK')
# actor('El Mariachi','Reinol Martinez')
# actor('Newlyweds','Caitlin Fitzgerald')
# actor('Signed, Sealed, Delivered','Geoff Gustafson')
# actor('Shanghai Calling','Alan Ruck')
# actor('My Date with Drew','Eric Roberts')
#    Call: (1) pyrun("assertz((actor('#Horror','Balthazar Getty'))).", _76) ?

# %%
# prolog.assertz('(directed_by(X,Y) :- findall(M,director(M,X),Y))')

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
def simple_recommender(movie):
    s = set()
    q = prolog.query("find_sim_1('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s:
            s.add(soln['M'])
    q.close()
    answers = s
    return answers

# %%
list(simple_recommender('Avatar'))[:5]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {i:i + 1 for i in range(1)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = simple_recommender(movie)

        for similar_movie in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[0]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[0] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
